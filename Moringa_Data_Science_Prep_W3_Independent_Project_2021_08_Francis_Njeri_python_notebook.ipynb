# %% [markdown]
# <a href="https://colab.research.google.com/github/franciskingk/week-3-ip/blob/main/Moringa_Data_Science_Prep_W3_Independent_Project_2021_08_Francis_Njeri_python_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import pandas
import pandas as pd
import numpy as np
import requests
import io

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-304871ea-c228-4ac4-a543-65098e8760c8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-304871ea-c228-4ac4-a543-65098e8760c8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CDR_description.xlsx to CDR_description.xlsx
# Saving cells_geo.csv to cells_geo.csv
# Saving cells_geo_description.xlsx to cells_geo_description.xlsx
# Saving Telcom_dataset.csv to Telcom_dataset.csv
# Saving Telcom_dataset3.csv to Telcom_dataset3.csv
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5ca984ce-c361-4f64-bb89-316a4bead129" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ca984ce-c361-4f64-bb89-316a4bead129">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cells_geo.csv to cells_geo.csv
# ...

# %%
# load cells_geo tables and data sets

cells_geo=pd.read_csv('/content/cells_geo.csv',sep=';')
cells_geo.head(5)
# Out:
#    Unnamed: 0   VILLES      STATUS  ... AREA     CELL_ID   SITE_CODE
# 0           0   ADJAME  In Service  ...  NaN  fbb2e75af3  0bb492ef17
# 1           1   ADJAME  In Service  ...  NaN  1502501d78  0bb492ef17
# 2           2   ADJAME  In Service  ...  NaN  0c2e182a0c  0bb492ef17
# 3           3  ASSINIE  In Service  ...  NaN  69bdfc69fd  8a1e6ce31f
# 4           4  ASSINIE  In Service  ...  NaN  7a1029d2ab  8a1e6ce31f
#
# [5 rows x 12 columns]

# %%
# load cells_description tables and data sets
df=pd.read_excel('/content/cells_geo_description.xlsx')
df
# Out:
#      Column name                                        Description  Format
# 0         VILLES                                               City  String
# 1         STATUS                                  In Service or not  String
# 2   LOCALISATION                                  in ABIDJAN or not  String
# 3     DECOUPZONE                                  Geographical Zone  String
# 4       ZONENAME                                       Name of Zone  String
# 5      LONGITUDE                                          Longitude   Float
# 6       LATITUDE                                           Latitude   Float
# 7         REGION                                             Region  String
# 8           AREA                                               Area  String
# 9        CELL_ID                                     ID of the cell  String
# 10     SITE_CODE  Site (there are several cells per site, severa...  String

# %%
# load CDR_description tables and data sets
CDR_description= pd.read_excel('/content/CDR_description.xlsx')
CDR_description
# Out:
#        Column name                                        Description   Format
# 0          PRODUCT                                       Voice or SMS   String
# 1            VALUE                                      Billing price  Integer
# 2        DATE_TIME               Time in format yyyy-MM-dd hh:mm:ss.0   String
# 3     CELL_ON_SITE  Which cell in the site was used (not needed here)  Integer
# 4  DW_A_NUMBER_INT  Anonymized phone number of the person for whic...   String
# 5  DW_B_NUMBER_INT        Anonymized phone number of the counterparty   String
# 6        COUNTRY_A                  Country of party A (useless here)   String
# 7        COUNTRY_B                  Country of party B (useless here)   String
# 8          CELL_ID                                     ID of the cell   String
# 9          SITE_ID                                     ID of the SITE   String

# %%
# load Telcom dataset_1 tables and data sets
dataset_1= pd.read_csv('/content/Telcom_dataset.csv')
dataset_1.head(5)
# Out:
#   PRODUTC  VALUE               DATETIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0   Voice      0  2012-05-06 23:04:37.0  ...     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1     sms      0  2012-05-06 23:05:25.0  ...     19e2e  /+cKZKIp41  /+cKZKIp41
# 2     sms     25  2012-05-06 23:05:41.0  ...     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3   Voice     56  2012-05-06 23:05:42.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     14  2012-05-06 23:06:29.0  ...     19e2e  051KhYDCpv  051KhYDCpv
#
# [5 rows x 10 columns]

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-474bd57a-67b8-4d24-8293-7301635fe65f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-474bd57a-67b8-4d24-8293-7301635fe65f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Telcom_dataset2.csv to Telcom_dataset2.csv
# ...

# %%
# load Telcom dataset_2 tables and data sets
dataset_2= pd.read_csv('/content/Telcom_dataset2.csv')
dataset_2.head(5)
# Out:
#   PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B     CELL_ID     SITE_ID
# 0     sms      0  2012-05-07 23:02:06.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 1   Voice      0  2012-05-07 23:03:44.0  ...     19e2e  +854AcBQT2  +854AcBQT2
# 2     sms      0  2012-05-07 23:04:06.0  ...     19e2e  +laSrk7g6q  +laSrk7g6q
# 3   Voice     37  2012-05-07 23:04:48.0  ...     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4     sms     25  2012-05-07 23:04:58.0  ...     19e2e  +bO+qkSonO  +bO+qkSonO
#
# [5 rows x 10 columns]

# %%
# load Telcom dataset_3 tables and data sets
dataset_3= pd.read_csv('/content/Telcom_dataset3.csv')
dataset_3.head(5)
# Out:
#   PRODUCT  VALUE              DATE_TIME  ... COUNTRY_B      CELLID     SIET_ID
# 0   Voice     61  2012-05-08 23:01:28.0  ...     19e2e  +38u2u/rfx  +38u2u/rfx
# 1     sms      0  2012-05-08 23:01:31.0  ...     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2   Voice     10  2012-05-08 23:02:59.0  ...     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3     sms      0  2012-05-08 23:03:04.0  ...     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4   Voice     22  2012-05-08 23:03:16.0  ...     19e2e  /eeMklgyJA  /eeMklgyJA
#
# [5 rows x 10 columns]

# %%
#Which ones were the most used cities for the three days?
#merging df 3 with cells geo
top_city=dataset_3.join(cells_geo,how='outer')

#remove NaN values
null=float('NaN')
top_city.replace("",our_null,inplace=True)
top_city.dropna()
# The most used city in the third day
top_city=merged_day3.groupby('VILLES').count()

#Sorting by value
top_city.sort_values(by=['VALUE'],ascending=0)
# Out:
#              PRODUCT  VALUE  DATE_TIME  ...  AREA  CELL_ID  SITE_CODE
# VILLES                                  ...
# COCODY           354    354        354  ...   354      354        354
# YOPOUGON         295    295        295  ...   295      295        295
# ABOBO            255    255        255  ...   247      255        255
# MARCORY          141    141        141  ...   141      141        141
# TREICHVILLE      132    132        132  ...   132      132        132
# ...              ...    ...        ...  ...   ...      ...        ...
# DOROPO             3      3          3  ...     3        3          3
# KOTOULA            2      2          2  ...     2        2          2
# MEMNI              2      2          2  ...     2        2          2
# OUANGOLO           1      1          1  ...     1        1          1
# DANANON            1      1          1  ...     1        1          1
#
# [504 rows x 21 columns]

# %%
#Which cities were the most used during business and home hours?

df["DATE_TIME"] = pd.to_datetime(df["DATE_TIME"])
df["hour"]= df["DATE_TIME"].dt.hour
df["minute"]= df["DATE_TIME"].dt.minute
top_city.sort_values(by=['VALUE'],ascending=0)
# Out:
#      PRODUCT  VALUE           DATE_TIME  ...     SIET_ID hour minute
# 0      Voice     61 2012-05-08 23:01:28  ...  +38u2u/rfx   23      1
# 1        sms      0 2012-05-08 23:01:31  ...  +Fs4mTvdKx   23      1
# 2      Voice     10 2012-05-08 23:02:59  ...  +ZaaZozy/+   23      2
# 3        sms      0 2012-05-08 23:03:04  ...  +cNeJzsTp3   23      3
# 4      Voice     22 2012-05-08 23:03:16  ...  /eeMklgyJA   23      3
# ...      ...    ...                 ...  ...         ...  ...    ...
# 4996   Voice      0 2012-05-09 00:01:43  ...  f7d63a29e5    0      1
# 4997   Voice     62 2012-05-09 00:01:43  ...  b4ddb9e93c    0      1
# 4998   Voice     32 2012-05-09 00:01:43  ...  d68260ef50    0      1
# 4999   Voice     30 2012-05-09 00:01:43  ...  b4130b54ab    0      1
# 5000   Voice     60 2012-05-09 00:01:43  ...  6d70dae094    0      1
#
# [5001 rows x 12 columns]
